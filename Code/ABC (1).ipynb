# %% [markdown]
# Sales and Profitability Analysis

# %% [raw]
# Step-1: Import the packages & Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_theme(style="darkgrid")
import inventorize3 as inv
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
dosya_yolu = r'C:\\Users\\The Capri Hotel\\Downloads\\sale.csv'

# %%
sales = pd.read_csv(dosya_yolu);sales.head()
# Out:
#    Order ID                   Product   Product_ean     catégorie  \
# 0    141234                    iPhone  5.638009e+12     Vêtements
# 1    141235  Lightning Charging Cable  5.563320e+12  Alimentation
# 2    141236          Wired Headphones  2.113973e+12     Vêtements
# 3    141237          27in FHD Monitor  3.069157e+12        Sports
# 4    141238          Wired Headphones  9.692681e+12  Électronique
#
#   Purchase Address  Quantity Ordered  Price Each  Cost price  turnover  \
# 0          Germany                 1      700.00    231.0000    700.00
# 1            İtaly                 1       14.95      7.4750     14.95
# 2           Ispain                 2       11.99      5.9950     23.98
# 3           Irland                 1      149.99     97.4935    149.99
# 4           France                 1       11.99      5.9950     11.99
#
#      margin           order_date         order_date.1         order_date.2
# 0  469.0000  2023-01-22 21:25:00  2023-01-22 21:25:00  2023-01-22 21:25:00
# 1    7.4750  2023-01-28 14:15:00  2023-01-28 14:15:00  2023-01-28 14:15:00
# 2   11.9900  2023-01-17 13:33:00  2023-01-17 13:33:00  2023-01-17 13:33:00
# 3   52.4965  2023-01-05 20:33:00  2023-01-05 20:33:00  2023-01-05 20:33:00
# 4    5.9950  2023-01-25 11:59:00  2023-01-25 11:59:00  2023-01-25 11:59:00

# %%
sales.shape
# Out:
# (168463, 13)

# %%
sales.dtypes
# Out:
# Order ID              int64
# Product              object
# Product_ean         float64
# catégorie            object
# Purchase Address     object
# Quantity Ordered      int64
# Price Each          float64
# Cost price          float64
# turnover            float64
# margin              float64
# order_date           object
# order_date.1         object
# order_date.2         object
# dtype: object

# %%
sales = sales.drop(columns=['order_date.2','order_date.1'])

# %%
# Minimum & Max date in dataset
sales['order_date'] = pd.to_datetime(sales['order_date'], format='%Y-%m-%d %H:%M:%S')
print(sales['order_date'].min(), sales['order_date'].max())
# Out:
# 2023-01-01 03:07:00 2023-12-31 23:53:00

# %%
col_mapping = {
                'Order ID': 'order_id',
                'Product': 'product',
                'Product_ean': 'product_code',
                'catégorie': 'category',
                'Purchase Address': 'address',
                'Quantity Ordered': 'quantity',
                'Price Each': 'price',
                'Cost price': 'cost',
                'turnover': 'sales',
                'margin': 'gross_profit'}

sales.columns = [col_mapping[col] if col in col_mapping else col for col in sales.columns]
sales.head()
# Out:
#    order_id                   product  product_code      category   address  \
# 0    141234                    iPhone  5.638009e+12     Vêtements   Germany
# 1    141235  Lightning Charging Cable  5.563320e+12  Alimentation     İtaly
# 2    141236          Wired Headphones  2.113973e+12     Vêtements    Ispain
# 3    141237          27in FHD Monitor  3.069157e+12        Sports    Irland
# 4    141238          Wired Headphones  9.692681e+12  Électronique    France
#
#    quantity   price      cost   sales  gross_profit          order_date
# 0         1  700.00  231.0000  700.00      469.0000 2023-01-22 21:25:00
# 1         1   14.95    7.4750   14.95        7.4750 2023-01-28 14:15:00
# 2         2   11.99    5.9950   23.98       11.9900 2023-01-17 13:33:00
# 3         1  149.99   97.4935  149.99       52.4965 2023-01-05 20:33:00
# 4         1   11.99    5.9950   11.99        5.9950 2023-01-25 11:59:00

# %%
cols = ['order_id', 'product_code']
sales[cols] = sales[cols].astype('str')
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168463 entries, 0 to 168462
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      168463 non-null  object
#  1   product       168463 non-null  object
#  2   product_code  168463 non-null  object
#  3   category      168463 non-null  object
#  4   address       168463 non-null  object
#  5   quantity      168463 non-null  int64
#  6   price         168463 non-null  float64
#  7   cost          168463 non-null  float64
#  8   sales         168463 non-null  float64
#  9   gross_profit  168463 non-null  float64
#  10  order_date    168463 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(1), object(5)
# memory usage: 14.1+ MB

# %%
# remove trailing dots and zeros from product_code values

sales['product_code'] = sales['product_code'].str[:-2]
sales.head()
# Out:
#   order_id                   product   product_code      category   address  \
# 0   141234                    iPhone  5638008983335     Vêtements   Germany
# 1   141235  Lightning Charging Cable  5563319511488  Alimentation     İtaly
# 2   141236          Wired Headphones  2113973395220     Vêtements    Ispain
# 3   141237          27in FHD Monitor  3069156759167        Sports    Irland
# 4   141238          Wired Headphones  9692680938163  Électronique    France
#
#    quantity   price      cost   sales  gross_profit          order_date
# 0         1  700.00  231.0000  700.00      469.0000 2023-01-22 21:25:00
# 1         1   14.95    7.4750   14.95        7.4750 2023-01-28 14:15:00
# 2         2   11.99    5.9950   23.98       11.9900 2023-01-17 13:33:00
# 3         1  149.99   97.4935  149.99       52.4965 2023-01-05 20:33:00
# 4         1   11.99    5.9950   11.99        5.9950 2023-01-25 11:59:00

# %%
# create gross_margin column
sales['gross_margin'] = (round(sales['gross_profit'] / sales['sales'], 2))
sales.head()
# Out:
#   order_id                   product   product_code      category   address  \
# 0   141234                    iPhone  5638008983335     Vêtements   Germany
# 1   141235  Lightning Charging Cable  5563319511488  Alimentation     İtaly
# 2   141236          Wired Headphones  2113973395220     Vêtements    Ispain
# 3   141237          27in FHD Monitor  3069156759167        Sports    Irland
# 4   141238          Wired Headphones  9692680938163  Électronique    France
#
#    quantity   price      cost   sales  gross_profit          order_date  \
# 0         1  700.00  231.0000  700.00      469.0000 2023-01-22 21:25:00
# 1         1   14.95    7.4750   14.95        7.4750 2023-01-28 14:15:00
# 2         2   11.99    5.9950   23.98       11.9900 2023-01-17 13:33:00
# 3         1  149.99   97.4935  149.99       52.4965 2023-01-05 20:33:00
# 4         1   11.99    5.9950   11.99        5.9950 2023-01-25 11:59:00
#
#    gross_margin
# 0          0.67
# 1          0.50
# 2          0.50
# 3          0.35
# 4          0.50

# %%
sales['cost'].value_counts()
# Out:
# cost
# 5.9750      19808
# 7.4750      19679
# 1.4950      18682
# 1.9200      18681
# 5.9950      17093
# 97.5000     14102
# 49.9950     12036
# 97.4935      6827
# 198.0000     6224
# 231.0000     6208
# 128.6967     5625
# 125.3967     5590
# 99.0000      4340
# 561.0000     4273
# 329.9967     3732
# 71.4935      3703
# 132.0000     1860
# Name: count, dtype: int64

# %%
sales['period'] = sales['order_date'].dt.to_period('M')
sales['dow'] = sales['order_date'].dt.day_name()
sales['hour'] = sales['order_date'].dt.strftime('%I %p')
sales['date'] = sales['order_date'].dt.date
sales.head()
# Out:
#   order_id                   product   product_code      category   address  \
# 0   141234                    iPhone  5638008983335     Vêtements   Germany
# 1   141235  Lightning Charging Cable  5563319511488  Alimentation     İtaly
# 2   141236          Wired Headphones  2113973395220     Vêtements    Ispain
# 3   141237          27in FHD Monitor  3069156759167        Sports    Irland
# 4   141238          Wired Headphones  9692680938163  Électronique    France
#
#    quantity   price      cost   sales  gross_profit          order_date  \
# 0         1  700.00  231.0000  700.00      469.0000 2023-01-22 21:25:00
# 1         1   14.95    7.4750   14.95        7.4750 2023-01-28 14:15:00
# 2         2   11.99    5.9950   23.98       11.9900 2023-01-17 13:33:00
# 3         1  149.99   97.4935  149.99       52.4965 2023-01-05 20:33:00
# 4         1   11.99    5.9950   11.99        5.9950 2023-01-25 11:59:00
#
#    gross_margin   period        dow   hour        date
# 0          0.67  2023-01     Sunday  09 PM  2023-01-22
# 1          0.50  2023-01   Saturday  02 PM  2023-01-28
# 2          0.50  2023-01    Tuesday  01 PM  2023-01-17
# 3          0.35  2023-01   Thursday  08 PM  2023-01-05
# 4          0.50  2023-01  Wednesday  11 AM  2023-01-25

# %%
sales['revenue']=sales['quantity']*sales['price']

# %%
sales['product'].value_counts()
# Out:
# product
# USB-C Charging Cable          19808
# Lightning Charging Cable      19679
# AAA Batteries (4-pack)        18682
# AA Batteries (4-pack)         18681
# Wired Headphones              17093
# Apple Airpods Headphones      14102
# Bose SoundSport Headphones    12036
# 27in FHD Monitor               6827
# iPhone                         6208
# 27in 4K Gaming Monitor         5625
# 34in Ultrawide Monitor         5590
# Google Phone                   5027
# Flatscreen TV                  4340
# Macbook Pro Laptop             4273
# ThinkPad Laptop                3732
# 20in Monitor                   3703
# Vareebadd Phone                1860
# LG Washing Machine              611
# LG Dryer                        586
# Name: count, dtype: int64

# %%
sales[sales['category'] == 'Sports']['product']
# Out:
# 3                 27in FHD Monitor
# 18            USB-C Charging Cable
# 23        Apple Airpods Headphones
# 24           AA Batteries (4-pack)
# 27            USB-C Charging Cable
#                     ...
# 168440                      iPhone
# 168443      27in 4K Gaming Monitor
# 168450        USB-C Charging Cable
# 168456        USB-C Charging Cable
# 168457            27in FHD Monitor
# Name: product, Length: 42570, dtype: object

# %%
sales[sales['category'] == 'Vêtements']['product']
# Out:
# 0                           iPhone
# 2                 Wired Headphones
# 6           27in 4K Gaming Monitor
# 7             USB-C Charging Cable
# 10        Apple Airpods Headphones
#                     ...
# 168434    Lightning Charging Cable
# 168441            Wired Headphones
# 168445      AAA Batteries (4-pack)
# 168452    Lightning Charging Cable
# 168455                      iPhone
# Name: product, Length: 41921, dtype: object

# %%
sales[sales['category'] == 'Électronique']['product']
# Out:
# 4                   Wired Headphones
# 8         Bose SoundSport Headphones
# 9           Apple Airpods Headphones
# 14                     Flatscreen TV
# 20            AAA Batteries (4-pack)
#                      ...
# 168446        AAA Batteries (4-pack)
# 168454      Lightning Charging Cable
# 168458              Wired Headphones
# 168460      Lightning Charging Cable
# 168461          USB-C Charging Cable
# Name: product, Length: 41945, dtype: object

# %%
sales[sales['category'] == 'Alimentation']['product']
# Out:
# 1           Lightning Charging Cable
# 5             AAA Batteries (4-pack)
# 15                  27in FHD Monitor
# 16                   Vareebadd Phone
# 17          Apple Airpods Headphones
#                      ...
# 168449    Bose SoundSport Headphones
# 168451      Lightning Charging Cable
# 168453        AAA Batteries (4-pack)
# 168459         AA Batteries (4-pack)
# 168462              27in FHD Monitor
# Name: product, Length: 42027, dtype: object

# %%
def change_cat(df):
    """ pass a dataframe and return category values based on product"""
    if df['product'] in ['AAA Batteries (4-pack)', 'AA Batteries (4-pack)']:
        return 'batteries'
    elif df['product'] in ['USB-C Charging Cable', 'Lightning Charging Cable']:
        return 'charging cables'
    elif df['product'] in ['LG Dryer', 'LG Washing Machine']:
        return 'appliance'
    elif df['product'] in ['Wired Headphones', 'Apple Airpods Headphones', 'Bose SoundSport Headphones']:
        return 'headphones'
    elif df['product'] in ['Macbook Pro Laptop', 'ThinkPad Laptop']:
        return 'laptops'
    elif df['product'] in ['iPhone', 'Google Phone', 'Vareebadd Phone']:
        return 'smartphones'
    elif df['product'] in ['27in FHD Monitor', '27in 4K Gaming Monitor', '34in Ultrawide Monitor','20in Monitor']:
        return 'monitors'
    elif df['product'] in ['Flatscreen TV']:
        return 'smartTV'
    else:
        return 'others'

# %%
sales['category'] = sales.apply(change_cat, axis =1)
sales.head()
# Out:
#   order_id                   product   product_code         category  \
# 0   141234                    iPhone  5638008983335      smartphones
# 1   141235  Lightning Charging Cable  5563319511488  charging cables
# 2   141236          Wired Headphones  2113973395220       headphones
# 3   141237          27in FHD Monitor  3069156759167         monitors
# 4   141238          Wired Headphones  9692680938163       headphones
#
#     address  quantity   price      cost   sales  gross_profit  \
# 0   Germany         1  700.00  231.0000  700.00      469.0000
# 1     İtaly         1   14.95    7.4750   14.95        7.4750
# 2    Ispain         2   11.99    5.9950   23.98       11.9900
# 3    Irland         1  149.99   97.4935  149.99       52.4965
# 4    France         1   11.99    5.9950   11.99        5.9950
#
#            order_date  gross_margin   period        dow   hour        date  \
# 0 2023-01-22 21:25:00          0.67  2023-01     Sunday  09 PM  2023-01-22
# 1 2023-01-28 14:15:00          0.50  2023-01   Saturday  02 PM  2023-01-28
# 2 2023-01-17 13:33:00          0.50  2023-01    Tuesday  01 PM  2023-01-17
# 3 2023-01-05 20:33:00          0.35  2023-01   Thursday  08 PM  2023-01-05
# 4 2023-01-25 11:59:00          0.50  2023-01  Wednesday  11 AM  2023-01-25
#
#    revenue
# 0   700.00
# 1    14.95
# 2    23.98
# 3   149.99
# 4    11.99

# %%
sales['category'].value_counts().plot(kind='bar', color='skyblue')

plt.title('Number of Sales by Category')
plt.xlabel('Category')
plt.ylabel('Number of Sales')
plt.xticks(rotation=45)  
plt.tight_layout()
plt.show()

# %%
sales['address'].value_counts().plot(kind='bar', color='skyblue')

plt.title('Number of Sales by Category')
plt.xlabel('Category')
plt.ylabel('Number of Sales')
plt.xticks(rotation=45)  
plt.tight_layout()
plt.show()

# %%
sales.describe()
# Out:
#             quantity          price           cost          sales  \
# count  168463.000000  168463.000000  168463.000000  168463.000000
# mean        1.124674     184.333657      69.652704     185.440054
# min         1.000000       2.990000       1.495000       2.990000
# 25%         1.000000      11.950000       5.975000      11.950000
# 50%         1.000000      14.950000       7.475000      14.950000
# 75%         1.000000     150.000000      97.500000     150.000000
# max         9.000000    1700.000000     561.000000    3400.000000
# std         0.443388     332.604926     109.385588     332.833643
#
#         gross_profit                     order_date   gross_margin  \
# count  168463.000000                         168463  168463.000000
# mean      115.249134  2023-07-03 06:07:53.856929792       0.516265
# min         1.495000            2023-01-01 03:07:00       0.350000
# 25%         5.975000            2023-04-09 19:27:30       0.500000
# 50%         7.475000            2023-06-28 22:31:00       0.500000
# 75%        52.500000            2023-10-06 01:53:30       0.500000
# max      2278.000000            2023-12-31 23:53:00       0.670000
# std       225.170138                            NaN       0.097565
#
#              revenue
# count  168463.000000
# mean      185.440054
# min         2.990000
# 25%        11.950000
# 50%        14.950000
# 75%       150.000000
# max      3400.000000
# std       332.833643

# %%
sales.describe(include = 'object')
# Out:
#        order_id               product   product_code    category  address  \
# count    168463                168463         168463      168463   168463
# unique   161119                    19         168463           8        9
# top      202348  USB-C Charging Cable  5638008983335  headphones   Ispain
# freq          6                 19808              1       43231    40455
#
#            dow    hour        date
# count   168463  168463      168463
# unique       7      24         365
# top     Sunday   07 PM  2023-10-26
# freq     24403   11664         713

# %%
sales.groupby('period').agg({
                        'sales': 'sum',
                        'gross_profit': 'sum'})
# Out:
#               sales  gross_profit
# period
# 2023-01  1813586.44  1.127681e+06
# 2023-02  2202022.42  1.369115e+06
# 2023-03  2807100.38  1.741473e+06
# 2023-04  3390670.24  2.109617e+06
# 2023-05  3152606.75  1.965322e+06
# 2023-06  2577802.26  1.602693e+06
# 2023-07  2647775.76  1.642685e+06
# 2023-08  2244467.88  1.396144e+06
# 2023-09  2097560.13  1.300184e+06
# 2023-10  3736726.88  2.325213e+06
# 2023-11  3199603.20  1.983143e+06
# 2023-12  1369865.49  8.519456e+05

# %%
sales.groupby('period').agg({
                        'sales': 'sum',
                        'gross_profit': 'sum'})
# Out:
#               sales  gross_profit
# period
# 2023-01  1813586.44  1.127681e+06
# 2023-02  2202022.42  1.369115e+06
# 2023-03  2807100.38  1.741473e+06
# 2023-04  3390670.24  2.109617e+06
# 2023-05  3152606.75  1.965322e+06
# 2023-06  2577802.26  1.602693e+06
# 2023-07  2647775.76  1.642685e+06
# 2023-08  2244467.88  1.396144e+06
# 2023-09  2097560.13  1.300184e+06
# 2023-10  3736726.88  2.325213e+06
# 2023-11  3199603.20  1.983143e+06
# 2023-12  1369865.49  8.519456e+05

# %%
sales.dtypes
# Out:
# order_id                object
# product                 object
# product_code            object
# category                object
# address                 object
# quantity                 int64
# price                  float64
# cost                   float64
# sales                  float64
# gross_profit           float64
# order_date      datetime64[ns]
# gross_margin           float64
# period               period[M]
# dow                     object
# hour                    object
# date                    object
# revenue                float64
# period_str              object
# dtype: object

# %%
sns.set_theme(style="whitegrid")
values = sales[['sales','gross_profit']]
dates = sales.period
data = pd.DataFrame({'period': sales['order_date'], 'sales': sales['sales'], 'gross_profit': sales['gross_profit']})
data = sales[[sales,period,gross_profit]]
data = data.rolling(7).mean()

sns.lineplot(data=data, palette="tab10", linewidth=2.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 5
#       3 dates = sales.period
#       4 data = pd.DataFrame({'period': sales['order_date'], 'sales': sales['sales'], 'gross_profit': sales['gross_profit']})
# ----> 5 data = sales[[sales,period,gross_profit]]
#       6 data = data.rolling(7).mean()
#       8 sns.lineplot(data=data, palette="tab10", linewidth=2.5)
#
# NameError: name 'period' is not defined

# %%
Grouped_sales = fr_sales.groupby('Purchase Address')
average_sales = Grouped_sales['Quantity Ordered'].mean()
print(average_sales)
# Out:
# Purchase Address
#  France        1.125997
#  Germany       1.130129
#  Hungary       1.122849
#  Irland        1.124438
#  Ispain        1.123111
#  Netherland    1.128880
#  Turkey        1.115651
#  UK            1.123608
#  İtaly         1.127397
# Name: Quantity Ordered, dtype: float64
